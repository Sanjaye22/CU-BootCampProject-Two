# %%
 #Dependencies
import pandas as pd

# %%
# The path to our CSV file
file = "Data/2010_infant_mortality.csv"

# Read our Kickstarter data into pandas
df = pd.read_csv(file)
df
# Out:
#     Unnamed: 0                 State  State,Code  Deaths  Births  Death  Rate
# 0          NaN               Alabama           1     524   60050   8.73   NaN
# 1          NaN                Alaska           2      41   11471   3.57   NaN
# 2          NaN               Arizona           4     520   87477   5.94   NaN
# 3          NaN              Arkansas           5     279   38540   7.24   NaN
# 4          NaN            California           6    2417  510198   4.74   NaN
# 5          NaN              Colorado           8     392   66355   5.91   NaN
# 6          NaN           Connecticut           9     200   37708   5.30   NaN
# 7          NaN              Delaware          10      85   11364   7.48   NaN
# 8          NaN  District,of,Columbia          11      70    9165   7.64   NaN
# 9          NaN               Florida          12    1397  214590   6.51   NaN
# 10         NaN               Georgia          13     849  133947   6.34   NaN
# ...

# %%
df.drop(labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors=‘raise’)
df
